# %% [raw]
# ---
# layout: post
# title: 2026 - Mathematical Expressions Homework
# categories: ['JavaScript']
# permalink: /javascript/math/Mathematical-Expressions-hw
# author: Samaghna Deshatty, Isha Chaturvedi, Ayden Dudley
# ---

# %% [markdown]
# # JS Lessons Mathematical Equations
#
# ## **Mathematical Expressions Homework**
# In order to learn this subject of programming and become proficient, you have to practice:
#
# > Problem 1: Simple plug in and experiment process!
#
# > Problem 2: a little harder, but still more of an experimental process so that you can understand what is going on!
#
# > Final Mission: A more complex version of what we have been doing, but it is still step by step to help you understand processes!
#
# > You don't have any more missions! But if you would like more practice, don't hesitate to reach out to us on slack. Try to reach out to <strong> Samaghna Deshatty (Assistant Scrum Master) </strong> or, <strong> Isha Chaturvedi (Scrum Master) </strong>
#
# ---

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>JavaScript Code Runners</title>
#   <style>
#     body { font-family: Arial, sans-serif; padding: 20px; }
#     textarea { width: 100%; height: 200px; font-family: monospace; }
#     .output { background: #111; color: rgb(0, 255, 242); padding: 10px; margin-top: 10px; min-height: 60px; white-space: pre-wrap; }
#     button { margin-top: 10px; padding: 8px 16px; font-size: 14px; }
#     .runner-box { margin-bottom: 60px; }
#   </style>
# </head>
# <body>
#
# For all of the questions below, we have implemented a "playground" type of work. We want you to do 2 things:
#  - Play around and see what is going on!
#  - Look at each function and each line of code and write down what each line does <strong> (That's the homework!) </strong>
#
# <!-- ===================== -->
# <!-- Practice Problem 1 -->
# <!-- ===================== -->
#
# <h2>Practice Problem 1</h2>
# <p><strong>Change the variables when you try it yourself!</strong></p>
#
# Once you are done playing around, make sure to <strong> add comments to define what the function of each line is! The comments are the actual homework! </strong>
#
# Pro Tip: The format for comments is // before any words you write
#
# <div class="runner-box">
#   <h3>JavaScript Code Runner 1</h3>
#   <textarea id="code1">
# // Example starter code
# let num = 10;
# let subtractResult = num - 4;
# let multiplyResult = num * 3;
# let moduloResult = num % 2;
#
# console.log(subtractResult, multiplyResult, moduloResult);
#   </textarea>
#   <br>
#   <button onclick="runCode('code1', 'output1')">Run Code</button>
#   <h3>Output:</h3>
#   <div id="output1" class="output"></div>
# </div>
#
# <!-- ===================== -->
# <!-- Practice Problem 2 -->
# <!-- ===================== -->
#
# <h2>Practice Problem 2</h2>
# <p><strong>Try changing a, b, and c to see different results.</strong></p>
#
# Once you are done playing around, make sure to <strong> add comments to define what the function of each line is! The comments are the actual homework! </strong>
#
# Pro Tip: The format for comments is // before any words you write
#
# <div class="runner-box">
#   <h3>JavaScript Code Runner 2</h3>
#   <textarea id="code2">
# // Example starter code
# let a = 6;
# let b = 2;
# let c = 3;
#
# let result = (a + b) * c - b;
# console.log(result);
#   </textarea>
#   <br>
#   <button onclick="runCode('code2', 'output2')">Run Code</button>
#   <h3>Output:</h3>
#   <div id="output2" class="output"></div>
# </div>
#
# <!-- ===================== -->
# <!-- Practice Problem 3 -->
# <!-- ===================== -->
#
# <h2>Practice Problem 3 — Final Mission</h2>
# <p><strong>Follow the steps and try changing x, y, and z.</strong></p>
#
# Once you are done playing around, make sure to <strong> add comments to define what the function of each line is! The comments are the actual homework! </strong>
#
# Pro Tip: The format for comments is // before any words you write
#
# <div class="runner-box">
#   <h3>JavaScript Code Runner 3</h3>
#   <textarea id="code3">
# // Example starter code
# let x = 8;
# let y = 3;
# let z = 2;
#
# let sumXY = x + y;
# let multiplied = sumXY * z;
# let finalResult = multiplied % y;
#
# console.log("x:", x);
# console.log("y:", y);
# console.log("z:", z);
# console.log("x + y =", sumXY);
# console.log("(x + y) * z =", multiplied);
# console.log("Final result:", finalResult);
#   </textarea>
#   <br>
#   <button onclick="runCode('code3', 'output3')">Run Code</button>
#   <h3>Output:</h3>
#   <div id="output3" class="output"></div>
# </div>
#
# <!-- ===================== -->
# <!-- UNIVERSAL JAVASCRIPT -->
# <!-- ===================== -->
#
# <script>
#   function runCode(codeId, outputId) {
#     const code = document.getElementById(codeId).value;
#     const outputDiv = document.getElementById(outputId);
#     outputDiv.textContent = '';
#
#     const originalLog = console.log;
#     console.log = function (...args) {
#       outputDiv.textContent += args.join(' ') + '\n';
#       originalLog.apply(console, args);
#     };
#
#     try {
#       new Function(code)();
#     } catch (err) {
#       outputDiv.textContent += 'Error: ' + err.message;
#     }
#
#     console.log = originalLog;
#   }
# </script>
#
# </body>
# </html>

# %% [markdown]
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfyhP_fNWQyqjIst4fnug6TWOUnwAZuY1cYIhYgYCBq4-X90A/viewform?usp=header"><b>Submission Google Form for Homework</b></a>
